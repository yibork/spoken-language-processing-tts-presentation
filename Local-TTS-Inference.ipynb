# %%
# !pip install speechbrain librosa matplotlib torchaudio
# Out:
# Requirement already satisfied: speechbrain in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (1.0.1)
# Collecting transformers
#   Downloading transformers-4.45.1-py3-none-any.whl.metadata (44 kB)
#      ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/44.4 kB 330.3 kB/s eta 0:00:01
#      -------------------------- ----------- 30.7/44.4 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 44.4/44.4 kB 313.2 kB/s eta 0:00:00
# Collecting librosa
#   Using cached librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: matplotlib in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: torchaudio in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: hyperpyyaml in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (1.2.2)
# Requirement already satisfied: joblib in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (1.4.2)
# Requirement already satisfied: numpy in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (1.26.4)
# Requirement already satisfied: packaging in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (23.2)
# Requirement already satisfied: scipy in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (1.13.1)
# Requirement already satisfied: sentencepiece in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (0.2.0)
# Requirement already satisfied: torch>=1.9 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (2.4.1)
# Requirement already satisfied: tqdm in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (4.66.4)
# Requirement already satisfied: huggingface-hub in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from speechbrain) (0.25.1)
# Requirement already satisfied: filelock in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from transformers) (2.32.2)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.5-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Downloading tokenizers-0.20.0-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from librosa) (0.59.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Using cached soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata (14 kB)
# Collecting pooch>=1.1 (from librosa)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.5.0.post1-cp312-abi3-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: sympy in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from torch>=1.9->speechbrain) (1.12)
# Requirement already satisfied: networkx in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from torch>=1.9->speechbrain) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from torch>=1.9->speechbrain) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from torch>=1.9->speechbrain) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from torch>=1.9->speechbrain) (69.5.1)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: colorama in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from tqdm->speechbrain) (0.4.6)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from hyperpyyaml->speechbrain) (0.18.6)
# Requirement already satisfied: pycparser in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from jinja2->torch>=1.9->speechbrain) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\yibor\appdata\local\anaconda3\lib\site-packages (from sympy->torch>=1.9->speechbrain) (1.3.0)
# Downloading transformers-4.45.1-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.9 MB 1.7 MB/s eta 0:00:06
#    ---------------------------------------- 0.1/9.9 MB 2.3 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.9 MB 1.6 MB/s eta 0:00:07
#     --------------------------------------- 0.2/9.9 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/9.9 MB 2.1 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/9.9 MB 2.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/9.9 MB 3.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/9.9 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 2.0/9.9 MB 5.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.3/9.9 MB 5.0 MB/s eta 0:00:02
#    ------------ --------------------------- 3.0/9.9 MB 5.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.9 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 4.9/9.9 MB 8.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.3/9.9 MB 8.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 8.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 9.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.5/9.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.5 MB/s eta 0:00:00
# Using cached librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading safetensors-0.4.5-cp312-none-win_amd64.whl (286 kB)
#    ---------------------------------------- 0.0/286.3 kB ? eta -:--:--
#    --------------------------------------- 286.3/286.3 kB 17.3 MB/s eta 0:00:00
# Using cached soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
# Downloading soxr-0.5.0.post1-cp312-abi3-win_amd64.whl (164 kB)
#    ---------------------------------------- 0.0/164.9 kB ? eta -:--:--
#    ---------------------------------------- 164.9/164.9 kB 9.7 MB/s eta 0:00:00
# Downloading tokenizers-0.20.0-cp312-none-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.3 MB 32.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.3 MB 15.4 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 18.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 16.3 MB/s eta 0:00:00
# Installing collected packages: soxr, safetensors, audioread, soundfile, pooch, tokenizers, librosa, transformers
# Successfully installed audioread-3.0.1 librosa-0.10.2.post1 pooch-1.8.2 safetensors-0.4.5 soundfile-0.12.1 soxr-0.5.0.post1 tokenizers-0.20.0 transformers-4.45.1

# %%
"""Author: yassine ibork"""

from speechbrain.pretrained import Tacotron2
from speechbrain.inference.vocoders import HIFIGAN
import tempfile
import torchaudio
import os

# Create a temporary directory for TTS and vocoder models
with tempfile.TemporaryDirectory() as tmpdir_tts, tempfile.TemporaryDirectory() as tmpdir_vocoder:
    # Initialize Tacotron2 TTS model
    tacotron2 = Tacotron2.from_hparams(source="speechbrain/tts-tacotron2-ljspeech", savedir=tmpdir_tts)
    
    # Initialize HiFIGAN vocoder
    hifi_gan = HIFIGAN.from_hparams(source="speechbrain/tts-hifigan-ljspeech", savedir=tmpdir_vocoder)
    
    # Running the TTS (text-to-mel-spectrogram)
    mel_output, mel_length, alignment = tacotron2.encode_text("Text-to-Speech (TTS) is a technology that converts written text into spoken words. It uses algorithms and voice synthesis techniques to produce speech that can be either robotic or human-like, depending on the quality of the synthesis engine. TTS systems are used in various applications, such as reading content aloud for people with visual impairments, voice assistants (e.g., Amazon Alexa, Google Assistant), and automated customer service. TTS solutions typically allow customization of language, voice type, speed, and tone, enabling more natural and context-appropriate audio output."
)
    
    # Running the vocoder (mel-spectrogram-to-waveform)
    waveforms = hifi_gan.decode_batch(mel_output)

# Save the audio file
output_directory = os.path.expanduser("~/GeneratedSpeech")  
output_file_path = os.path.join(output_directory, "generated_speech.wav")

# Save the waveform as an audio file
torchaudio.save(output_file_path, waveforms.squeeze(1), 22050)

print(f"Audio saved to {output_file_path}")
# Out:
# Audio saved to C:\Users\yibor/Documents/wsu/fall 2024/spoken language processing/presentation/GeneratedSpeech\generated_speech.wav
